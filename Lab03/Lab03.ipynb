# %% [markdown]
# #  Phân biệt các Thuật ngữ Khoa học dữ liệu, phân tích dữ liệu và kỹ sư dữ liệu

# %% [markdown]
# **Bối cảnh chung**: Hiện tại đang có:
# - 2 file dữ liệu Orders khác nhau
# - 1 file Product
# - 1 file Customer
#
# **Mục tiêu cuối cùng**:
# Tạo ra 1 dataset Orders duy nhất, sạch, chuẩn hoá, có thể join chính xác với Product và Customer, phục vụ phân tích và mô hình ML.

# %% [markdown]
# ## 1. Data Engineering
# #### Nhiệm vụ: Thu thập và chuẩn hóa dữ liệu từ các nguồn khác nhau thành một "Single Source of Truth".

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
working_path = "/content/drive/My Drive/HCMUS/Intro2DS/Lab/Lab03/"

# %% [markdown]
# ### 1.1 Data preprocessing: Orders

# %%
df_orders_Q1 = pd.read_csv(working_path + 'lab03_Orders_Q1.csv')

# %%
df_orders_Q1
# Out:
#            Order_ID  Order_Date Order_Priority Customer_ID      Industry_name  \
# 0    HC-2011-103800      1/4/24         Medium    DP-13000  Thiết bị gia dụng
# 1    NA-2011-112326  2024.01.05         Medium    PO-19195  Thiết bị gia dụng
# 2    NA-2011-112326      1/5/24            Low    PO-19195  Thiết bị gia dụng
# 3    NA-2011-112326      1/5/24            Low    PO-19195  Thiết bị gia dụng
# 4    TN-2011-141817      1/6/24         Medium    MB-18085  Thiết bị gia dụng
# ..              ...         ...            ...         ...                ...
# 276  HC-2011-104759  2024-03-32         Medium    DD-13570   Thiết bị điện tử
# 277  HC-2011-101770     3/31/24            Low    KB-16240  Thiết bị gia dụng
# 278  ĐT-2011-130428     3/31/24           High    TG-21640  Thiết bị gia dụng
# 279  ĐT-2011-130428     3/31/24            Low    TG-21640  Thiết bị gia dụng
# 280  ĐT-2011-130428     3/31/24         Medium    TG-21640  Thiết bị gia dụng
#
#         Province            Region Channel       Product_ID     Sales  \
# 0    Hồ Chí Minh  Miền Đông Nam Bộ   Store  OFF-PA-10000174    16.448
# 1        Nghệ An        Miền Trung  Online  OFF-LA-10003223    11.784
# 2        Nghệ An        Miền Trung  Online  OFF-ST-10002743   272.736
# 3        Nghệ An  Miền Đông Nam Bộ  Online  OFF-BI-10004094     3.540
# 4      Tây Ninh   Miền Đông Nam Bộ   Store  OFF-AR-10003478    19.536
# ..           ...               ...     ...              ...       ...
# 276  Hồ Chí Minh  Miền Đông Nam Bộ   Agent  TEC-AC-10004901    79.984
# 277  Hồ Chí Minh  Miền Đông Nam Bộ   Agent  OFF-BI-10001097     1.869
# 278    Đồng Tháp   Miền Tây Nam Bộ   Agent  FUR-CH-10002965  1125.488
# 279    Đồng Tháp   Miền Tây Nam Bộ   Agent  OFF-BI-10001636    12.645
# 280    Đồng Tháp   Miền Tây Nam Bộ   Agent  OFF-AR-10004027     4.032
#
#      Quantity  Unit_Price  Discount   Profit Returned_Reason
# 0         2.0       8.224       0.2   5.5512       No reason
# 1         3.0       3.928       0.2   4.2717              ""
# 2         3.0      90.912       0.2 -64.7748              ""
# 3         2.0         NaN       0.8  -5.4870             NaN
# 4         3.0       6.512       0.2   4.8840             NaN
# ..        ...         ...       ...      ...             ...
# 276       2.0      39.992       0.2  13.9972             NaN
# 277       1.0       1.869       0.7  -1.3083             NaN
# 278       7.0     160.784       0.2  98.4802             NaN
# 279       5.0       2.529       0.7 -10.1160             NaN
# 280       2.0       2.016       0.2   1.0584             NaN
#
# [281 rows x 15 columns]

# %%
df_orders_Q2 = pd.read_csv(working_path + 'lab03_Orders_Q2.csv')

# %%
df_orders_Q2
# Out:
#            Order_ID Order_Date Order_Priority Customer_ID      Industry_name  \
# 0    ĐN-2011-107181    5/12/24         Medium    DB-13270  Thiết bị gia dụng
# 1    TG-2011-157021     4/1/24         Medium    KM-16720  Thiết bị gia dụng
# 2    TG-2011-157021     4/1/24         Medium    KM-16720  Thiết bị gia dụng
# 3    TG-2011-138359     4/1/24         Medium    KH-16330  Thiết bị gia dụng
# 4    TG-2011-138359     4/1/24         Medium    KH-16330  Thiết bị gia dụng
# ..              ...        ...            ...         ...                ...
# 217  HT-2011-127166    5/21/24         Medium    KH-16360  Thiết bị gia dụng
# 218  HT-2011-127166    5/21/24            Low    KH-16360  Thiết bị gia dụng
# 219  HT-2011-127166    5/21/24            Low    KH-16360  Thiết bị gia dụng
# 220  HC-2011-130673    5/20/24            Low    MC-17590  Thiết bị gia dụng
# 221  HC-2011-113768    5/13/24         Medium    AH-10030  Thiết bị gia dụng
#
#         Province            Region Channel       Product_ID    Sales  \
# 0        Đà Nẵng        Miền Trung   Store  OFF-BI-10004230   82.896
# 1     Tiền Giang   Miền Tây Nam Bộ   Store  OFF-LA-10002312   29.600
# 2     Tiền Giang   Miền Tây Nam Bộ   Store  OFF-BI-10000042   17.088
# 3     Tiền Giang   Miền Tây Nam Bộ   Agent  OFF-ST-10000636   66.960
# 4     Tiền Giang   Miền Tây Nam Bộ   Agent  OFF-BI-10000145    6.240
# ..           ...               ...     ...              ...      ...
# 217      Hà Tỉnh        Miền Trung   Agent  OFF-PA-10001560    4.832
# 218      Hà Tỉnh        Miền Trung   Agent  OFF-BI-10000977   18.240
# 219      Hà Tỉnh        Miền Trung   Agent  OFF-BI-10000977   18.240
# 220  Hồ Chí Minh  Miền Đông Nam Bộ   Agent  OFF-ST-10000636   66.960
# 221  Hồ Chí Minh  Miền Đông Nam Bộ   Agent  FUR-CH-10002439  279.456
#
#      Quantity   Price  Discount   Profit  Returned_Reason  Notes
# 0         3.0  27.632       0.2  29.0136              NaN    NaN
# 1         2.0  14.800       0.0  14.8000              NaN    NaN
# 2         4.0   4.272       0.2   5.5536              NaN    NaN
# 3         4.0  16.740       0.0   2.6784              NaN    NaN
# 4         2.0   3.120       0.0   3.0576              NaN    NaN
# ..        ...     ...       ...      ...              ...    ...
# 217       1.0   4.832       0.2   1.6308              NaN    NaN
# 218       3.0   6.080       0.8 -31.0080              NaN    NaN
# 219       3.0   6.080       0.8 -31.0080              NaN    NaN
# 220       5.0  13.392       0.2 -13.3920              NaN    NaN
# 221       6.0  46.576       0.2  20.9592              NaN    NaN
#
# [222 rows x 16 columns]

# %%
df_orders_Q1.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Order_Priority', 'Customer_ID',
#        'Industry_name', 'Province', 'Region', 'Channel', 'Product_ID', 'Sales',
#        'Quantity', 'Unit_Price', 'Discount', 'Profit', 'Returned_Reason'],
#       dtype='object')

# %%
df_orders_Q2.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Order_Priority', 'Customer_ID',
#        'Industry_name', 'Province', 'Region', 'Channel', 'Product_ID', 'Sales',
#        'Quantity', 'Price', 'Discount', 'Profit', 'Returned_Reason', 'Notes'],
#       dtype='object')

# %% [markdown]
# **Nhận xét**: df_orders_Q1 và df_orders_Q2
# - có số lượng cols khác nhau
# - Có 1 số cột khác nhau
# ==> Xử lý:
# - Đồng nhất tên các cột có cùng ý nghĩa nhưng khác tên
# - Chọn ra các cols có ý nghĩa hoặc cần sử dụng

# %%
# Rename Price thành Unit_Price
df_orders_Q2 = df_orders_Q2.rename(columns={'Price':"Unit_Price"})

# %%
df_orders_Q2
# Out:
#            Order_ID Order_Date Order_Priority Customer_ID      Industry_name  \
# 0    ĐN-2011-107181    5/12/24         Medium    DB-13270  Thiết bị gia dụng
# 1    TG-2011-157021     4/1/24         Medium    KM-16720  Thiết bị gia dụng
# 2    TG-2011-157021     4/1/24         Medium    KM-16720  Thiết bị gia dụng
# 3    TG-2011-138359     4/1/24         Medium    KH-16330  Thiết bị gia dụng
# 4    TG-2011-138359     4/1/24         Medium    KH-16330  Thiết bị gia dụng
# ..              ...        ...            ...         ...                ...
# 217  HT-2011-127166    5/21/24         Medium    KH-16360  Thiết bị gia dụng
# 218  HT-2011-127166    5/21/24            Low    KH-16360  Thiết bị gia dụng
# 219  HT-2011-127166    5/21/24            Low    KH-16360  Thiết bị gia dụng
# 220  HC-2011-130673    5/20/24            Low    MC-17590  Thiết bị gia dụng
# 221  HC-2011-113768    5/13/24         Medium    AH-10030  Thiết bị gia dụng
#
#         Province            Region Channel       Product_ID    Sales  \
# 0        Đà Nẵng        Miền Trung   Store  OFF-BI-10004230   82.896
# 1     Tiền Giang   Miền Tây Nam Bộ   Store  OFF-LA-10002312   29.600
# 2     Tiền Giang   Miền Tây Nam Bộ   Store  OFF-BI-10000042   17.088
# 3     Tiền Giang   Miền Tây Nam Bộ   Agent  OFF-ST-10000636   66.960
# 4     Tiền Giang   Miền Tây Nam Bộ   Agent  OFF-BI-10000145    6.240
# ..           ...               ...     ...              ...      ...
# 217      Hà Tỉnh        Miền Trung   Agent  OFF-PA-10001560    4.832
# 218      Hà Tỉnh        Miền Trung   Agent  OFF-BI-10000977   18.240
# 219      Hà Tỉnh        Miền Trung   Agent  OFF-BI-10000977   18.240
# 220  Hồ Chí Minh  Miền Đông Nam Bộ   Agent  OFF-ST-10000636   66.960
# 221  Hồ Chí Minh  Miền Đông Nam Bộ   Agent  FUR-CH-10002439  279.456
#
#      Quantity  Unit_Price  Discount   Profit  Returned_Reason  Notes
# 0         3.0      27.632       0.2  29.0136              NaN    NaN
# 1         2.0      14.800       0.0  14.8000              NaN    NaN
# 2         4.0       4.272       0.2   5.5536              NaN    NaN
# 3         4.0      16.740       0.0   2.6784              NaN    NaN
# 4         2.0       3.120       0.0   3.0576              NaN    NaN
# ..        ...         ...       ...      ...              ...    ...
# 217       1.0       4.832       0.2   1.6308              NaN    NaN
# 218       3.0       6.080       0.8 -31.0080              NaN    NaN
# 219       3.0       6.080       0.8 -31.0080              NaN    NaN
# 220       5.0      13.392       0.2 -13.3920              NaN    NaN
# 221       6.0      46.576       0.2  20.9592              NaN    NaN
#
# [222 rows x 16 columns]

# %%
cols = df_orders_Q1.columns.to_list()

# %%
cols
# Out:
# ['Order_ID',
#  'Order_Date',
#  'Order_Priority',
#  'Customer_ID',
#  'Industry_name',
#  'Province',
#  'Region',
#  'Channel',
#  'Product_ID',
#  'Sales',
#  'Quantity',
#  'Unit_Price',
#  'Discount',
#  'Profit',
#  'Returned_Reason']

# %%
df_orders_Q2 = df_orders_Q2[cols]

# %%
df_orders_Q2
# Out:
#            Order_ID Order_Date Order_Priority Customer_ID      Industry_name  \
# 0    ĐN-2011-107181    5/12/24         Medium    DB-13270  Thiết bị gia dụng
# 1    TG-2011-157021     4/1/24         Medium    KM-16720  Thiết bị gia dụng
# 2    TG-2011-157021     4/1/24         Medium    KM-16720  Thiết bị gia dụng
# 3    TG-2011-138359     4/1/24         Medium    KH-16330  Thiết bị gia dụng
# 4    TG-2011-138359     4/1/24         Medium    KH-16330  Thiết bị gia dụng
# ..              ...        ...            ...         ...                ...
# 217  HT-2011-127166    5/21/24         Medium    KH-16360  Thiết bị gia dụng
# 218  HT-2011-127166    5/21/24            Low    KH-16360  Thiết bị gia dụng
# 219  HT-2011-127166    5/21/24            Low    KH-16360  Thiết bị gia dụng
# 220  HC-2011-130673    5/20/24            Low    MC-17590  Thiết bị gia dụng
# 221  HC-2011-113768    5/13/24         Medium    AH-10030  Thiết bị gia dụng
#
#         Province            Region Channel       Product_ID    Sales  \
# 0        Đà Nẵng        Miền Trung   Store  OFF-BI-10004230   82.896
# 1     Tiền Giang   Miền Tây Nam Bộ   Store  OFF-LA-10002312   29.600
# 2     Tiền Giang   Miền Tây Nam Bộ   Store  OFF-BI-10000042   17.088
# 3     Tiền Giang   Miền Tây Nam Bộ   Agent  OFF-ST-10000636   66.960
# 4     Tiền Giang   Miền Tây Nam Bộ   Agent  OFF-BI-10000145    6.240
# ..           ...               ...     ...              ...      ...
# 217      Hà Tỉnh        Miền Trung   Agent  OFF-PA-10001560    4.832
# 218      Hà Tỉnh        Miền Trung   Agent  OFF-BI-10000977   18.240
# 219      Hà Tỉnh        Miền Trung   Agent  OFF-BI-10000977   18.240
# 220  Hồ Chí Minh  Miền Đông Nam Bộ   Agent  OFF-ST-10000636   66.960
# 221  Hồ Chí Minh  Miền Đông Nam Bộ   Agent  FUR-CH-10002439  279.456
#
#      Quantity  Unit_Price  Discount   Profit  Returned_Reason
# 0         3.0      27.632       0.2  29.0136              NaN
# 1         2.0      14.800       0.0  14.8000              NaN
# 2         4.0       4.272       0.2   5.5536              NaN
# 3         4.0      16.740       0.0   2.6784              NaN
# 4         2.0       3.120       0.0   3.0576              NaN
# ..        ...         ...       ...      ...              ...
# 217       1.0       4.832       0.2   1.6308              NaN
# 218       3.0       6.080       0.8 -31.0080              NaN
# 219       3.0       6.080       0.8 -31.0080              NaN
# 220       5.0      13.392       0.2 -13.3920              NaN
# 221       6.0      46.576       0.2  20.9592              NaN
#
# [222 rows x 15 columns]

# %%
# union 2 files
df_orders = pd.concat([df_orders_Q1, df_orders_Q2], ignore_index=True)
df_orders
# Out:
#            Order_ID  Order_Date Order_Priority Customer_ID      Industry_name  \
# 0    HC-2011-103800      1/4/24         Medium    DP-13000  Thiết bị gia dụng
# 1    NA-2011-112326  2024.01.05         Medium    PO-19195  Thiết bị gia dụng
# 2    NA-2011-112326      1/5/24            Low    PO-19195  Thiết bị gia dụng
# 3    NA-2011-112326      1/5/24            Low    PO-19195  Thiết bị gia dụng
# 4    TN-2011-141817      1/6/24         Medium    MB-18085  Thiết bị gia dụng
# ..              ...         ...            ...         ...                ...
# 498  HT-2011-127166     5/21/24         Medium    KH-16360  Thiết bị gia dụng
# 499  HT-2011-127166     5/21/24            Low    KH-16360  Thiết bị gia dụng
# 500  HT-2011-127166     5/21/24            Low    KH-16360  Thiết bị gia dụng
# 501  HC-2011-130673     5/20/24            Low    MC-17590  Thiết bị gia dụng
# 502  HC-2011-113768     5/13/24         Medium    AH-10030  Thiết bị gia dụng
#
#         Province            Region Channel       Product_ID    Sales  \
# 0    Hồ Chí Minh  Miền Đông Nam Bộ   Store  OFF-PA-10000174   16.448
# 1        Nghệ An        Miền Trung  Online  OFF-LA-10003223   11.784
# 2        Nghệ An        Miền Trung  Online  OFF-ST-10002743  272.736
# 3        Nghệ An  Miền Đông Nam Bộ  Online  OFF-BI-10004094    3.540
# 4      Tây Ninh   Miền Đông Nam Bộ   Store  OFF-AR-10003478   19.536
# ..           ...               ...     ...              ...      ...
# 498      Hà Tỉnh        Miền Trung   Agent  OFF-PA-10001560    4.832
# 499      Hà Tỉnh        Miền Trung   Agent  OFF-BI-10000977   18.240
# 500      Hà Tỉnh        Miền Trung   Agent  OFF-BI-10000977   18.240
# 501  Hồ Chí Minh  Miền Đông Nam Bộ   Agent  OFF-ST-10000636   66.960
# 502  Hồ Chí Minh  Miền Đông Nam Bộ   Agent  FUR-CH-10002439  279.456
#
#      Quantity  Unit_Price  Discount   Profit Returned_Reason
# 0         2.0       8.224       0.2   5.5512       No reason
# 1         3.0       3.928       0.2   4.2717              ""
# 2         3.0      90.912       0.2 -64.7748              ""
# 3         2.0         NaN       0.8  -5.4870             NaN
# 4         3.0       6.512       0.2   4.8840             NaN
# ..        ...         ...       ...      ...             ...
# 498       1.0       4.832       0.2   1.6308             NaN
# 499       3.0       6.080       0.8 -31.0080             NaN
# 500       3.0       6.080       0.8 -31.0080             NaN
# 501       5.0      13.392       0.2 -13.3920             NaN
# 502       6.0      46.576       0.2  20.9592             NaN
#
# [503 rows x 15 columns]

# %% [markdown]
# ### 1.2 Data preprocessing: Customers

# %%
df_cus = pd.read_csv(working_path + 'lab03_CUS.csv')

# %%
df_cus
# Out:
#     Customer_ID         Customer_Name Customer_Segment Birthday  Phone number  \
# 0      DP-13000           Darren Tran         Consumer  1/11/70     909123123
# 1      PO-19195         Phillina Ober      Home Office  9/14/84     909123124
# 2      MB-18085            Trần Nhiễm         Consumer  1/11/96     909123127
# 3      LS-17230      Lycoris Saunders         Consumer  1/11/82     909123128
# 4      JO-15145         Jack O'Briant        Corporate  1/11/80     909123129
# ..          ...                   ...              ...      ...           ...
# 211    RF-19345        Randy Ferguson        Corporate  1/11/82     909123606
# 212    MC-17590  Nguyễn Thị Thu Hường        Corporate  1/11/79     909123609
# 213    MW-18235      Mitch Willingham        Corporate  1/11/89     909123613
# 214    BT-11530              Trần Lựu      Home Office  1/11/86     909123615
# 215    FG-14260         Trà Ngọc Hằng      Home Office  1/11/89     909123617
#
#           Province
# 0         Vĩnh Long
# 1            TP HCM
# 2        Bình Dương
# 3         Vĩnh Phúc
# 4        Bình Dương
# ..              ...
# 211      Bình Dương
# 212         Hà Tỉnh
# 213     Hồ Chí Minh
# 214     Hồ Chí Minh
# 215  Thừa Thiên Huế
#
# [216 rows x 6 columns]

# %% [markdown]
# ### 1.3. Join 2 df: Orders & Customers

# %% [markdown]
# ### 1.3.1 Join 2 df với cùng tên cột join

# %%
df_orders_cus = df_orders.merge(df_cus, on="Customer_ID", how="inner")

# %%
df_orders_cus
# Out:
#            Order_ID  Order_Date Order_Priority Customer_ID      Industry_name  \
# 0    HC-2011-103800      1/4/24         Medium    DP-13000  Thiết bị gia dụng
# 1    NA-2011-112326  2024.01.05         Medium    PO-19195  Thiết bị gia dụng
# 2    NA-2011-112326      1/5/24            Low    PO-19195  Thiết bị gia dụng
# 3    NA-2011-112326      1/5/24            Low    PO-19195  Thiết bị gia dụng
# 4    TN-2011-141817      1/6/24         Medium    MB-18085  Thiết bị gia dụng
# ..              ...         ...            ...         ...                ...
# 497  HT-2011-127166     5/21/24         Medium    KH-16360  Thiết bị gia dụng
# 498  HT-2011-127166     5/21/24            Low    KH-16360  Thiết bị gia dụng
# 499  HT-2011-127166     5/21/24            Low    KH-16360  Thiết bị gia dụng
# 500  HC-2011-130673     5/20/24            Low    MC-17590  Thiết bị gia dụng
# 501  HC-2011-113768     5/13/24         Medium    AH-10030  Thiết bị gia dụng
#
#         Province            Region Channel       Product_ID    Sales  \
# 0    Hồ Chí Minh  Miền Đông Nam Bộ   Store  OFF-PA-10000174   16.448
# 1        Nghệ An        Miền Trung  Online  OFF-LA-10003223   11.784
# 2        Nghệ An        Miền Trung  Online  OFF-ST-10002743  272.736
# 3        Nghệ An  Miền Đông Nam Bộ  Online  OFF-BI-10004094    3.540
# 4      Tây Ninh   Miền Đông Nam Bộ   Store  OFF-AR-10003478   19.536
# ..           ...               ...     ...              ...      ...
# 497      Hà Tỉnh        Miền Trung   Agent  OFF-PA-10001560    4.832
# 498      Hà Tỉnh        Miền Trung   Agent  OFF-BI-10000977   18.240
# 499      Hà Tỉnh        Miền Trung   Agent  OFF-BI-10000977   18.240
# 500  Hồ Chí Minh  Miền Đông Nam Bộ   Agent  OFF-ST-10000636   66.960
# 501  Hồ Chí Minh  Miền Đông Nam Bộ   Agent  FUR-CH-10002439  279.456
#
#      Quantity  Unit_Price  Discount   Profit Returned_Reason  \
# 0         2.0       8.224       0.2   5.5512       No reason
# 1         3.0       3.928       0.2   4.2717              ""
# 2         3.0      90.912       0.2 -64.7748              ""
# 3         2.0         NaN       0.8  -5.4870             NaN
# 4         3.0       6.512       0.2   4.8840             NaN
# ..        ...         ...       ...      ...             ...
# 497       1.0       4.832       0.2   1.6308             NaN
# 498       3.0       6.080       0.8 -31.0080             NaN
# 499       3.0       6.080       0.8 -31.0080             NaN
# 500       5.0      13.392       0.2 -13.3920             NaN
# 501       6.0      46.576       0.2  20.9592             NaN
#
#             Customer_Name Customer_Segment Birthday  Phone number    Province
# 0             Darren Tran         Consumer  1/11/70     909123123    Vĩnh Long
# 1           Phillina Ober      Home Office  9/14/84     909123124       TP HCM
# 2           Phillina Ober      Home Office  9/14/84     909123124       TP HCM
# 3           Phillina Ober      Home Office  9/14/84     909123124       TP HCM
# 4              Trần Nhiễm         Consumer  1/11/96     909123127   Bình Dương
# ..                    ...              ...      ...           ...          ...
# 497              Trần Đức         Consumer  1/11/87     909123536       Hà Nội
# 498              Trần Đức         Consumer  1/11/87     909123536       Hà Nội
# 499              Trần Đức         Consumer  1/11/87     909123536       Hà Nội
# 500  Nguyễn Thị Thu Hường        Corporate  1/11/79     909123609      Hà Tỉnh
# 501      Trương Thanh Vân        Corporate  1/11/80     909123504  Hồ Chí Minh
#
# [502 rows x 20 columns]

# %%
df_orders_cus = df_orders.merge(df_cus, on="Customer_ID", how="left")

# %%
df_orders_cus
# Out:
#            Order_ID  Order_Date Order_Priority Customer_ID      Industry_name  \
# 0    HC-2011-103800      1/4/24         Medium    DP-13000  Thiết bị gia dụng
# 1    NA-2011-112326  2024.01.05         Medium    PO-19195  Thiết bị gia dụng
# 2    NA-2011-112326      1/5/24            Low    PO-19195  Thiết bị gia dụng
# 3    NA-2011-112326      1/5/24            Low    PO-19195  Thiết bị gia dụng
# 4    TN-2011-141817      1/6/24         Medium    MB-18085  Thiết bị gia dụng
# ..              ...         ...            ...         ...                ...
# 498  HT-2011-127166     5/21/24         Medium    KH-16360  Thiết bị gia dụng
# 499  HT-2011-127166     5/21/24            Low    KH-16360  Thiết bị gia dụng
# 500  HT-2011-127166     5/21/24            Low    KH-16360  Thiết bị gia dụng
# 501  HC-2011-130673     5/20/24            Low    MC-17590  Thiết bị gia dụng
# 502  HC-2011-113768     5/13/24         Medium    AH-10030  Thiết bị gia dụng
#
#         Province            Region Channel       Product_ID    Sales  \
# 0    Hồ Chí Minh  Miền Đông Nam Bộ   Store  OFF-PA-10000174   16.448
# 1        Nghệ An        Miền Trung  Online  OFF-LA-10003223   11.784
# 2        Nghệ An        Miền Trung  Online  OFF-ST-10002743  272.736
# 3        Nghệ An  Miền Đông Nam Bộ  Online  OFF-BI-10004094    3.540
# 4      Tây Ninh   Miền Đông Nam Bộ   Store  OFF-AR-10003478   19.536
# ..           ...               ...     ...              ...      ...
# 498      Hà Tỉnh        Miền Trung   Agent  OFF-PA-10001560    4.832
# 499      Hà Tỉnh        Miền Trung   Agent  OFF-BI-10000977   18.240
# 500      Hà Tỉnh        Miền Trung   Agent  OFF-BI-10000977   18.240
# 501  Hồ Chí Minh  Miền Đông Nam Bộ   Agent  OFF-ST-10000636   66.960
# 502  Hồ Chí Minh  Miền Đông Nam Bộ   Agent  FUR-CH-10002439  279.456
#
#      Quantity  Unit_Price  Discount   Profit Returned_Reason  \
# 0         2.0       8.224       0.2   5.5512       No reason
# 1         3.0       3.928       0.2   4.2717              ""
# 2         3.0      90.912       0.2 -64.7748              ""
# 3         2.0         NaN       0.8  -5.4870             NaN
# 4         3.0       6.512       0.2   4.8840             NaN
# ..        ...         ...       ...      ...             ...
# 498       1.0       4.832       0.2   1.6308             NaN
# 499       3.0       6.080       0.8 -31.0080             NaN
# 500       3.0       6.080       0.8 -31.0080             NaN
# 501       5.0      13.392       0.2 -13.3920             NaN
# 502       6.0      46.576       0.2  20.9592             NaN
#
#             Customer_Name Customer_Segment Birthday  Phone number    Province
# 0             Darren Tran         Consumer  1/11/70   909123123.0    Vĩnh Long
# 1           Phillina Ober      Home Office  9/14/84   909123124.0       TP HCM
# 2           Phillina Ober      Home Office  9/14/84   909123124.0       TP HCM
# 3           Phillina Ober      Home Office  9/14/84   909123124.0       TP HCM
# 4              Trần Nhiễm         Consumer  1/11/96   909123127.0   Bình Dương
# ..                    ...              ...      ...           ...          ...
# 498              Trần Đức         Consumer  1/11/87   909123536.0       Hà Nội
# 499              Trần Đức         Consumer  1/11/87   909123536.0       Hà Nội
# 500              Trần Đức         Consumer  1/11/87   909123536.0       Hà Nội
# 501  Nguyễn Thị Thu Hường        Corporate  1/11/79   909123609.0      Hà Tỉnh
# 502      Trương Thanh Vân        Corporate  1/11/80   909123504.0  Hồ Chí Minh
#
# [503 rows x 20 columns]

# %% [markdown]
# ### 1.3.2 Join 2 df với cùng khác tên cột join

# %%
df_orders_cus_1 = df_orders.merge(df_cus, left_on="Customer_ID", right_on="Customer_ID", how="left")
df_orders_cus_1
# Out:
#            Order_ID  Order_Date Order_Priority Customer_ID      Industry_name  \
# 0    HC-2011-103800      1/4/24         Medium    DP-13000  Thiết bị gia dụng
# 1    NA-2011-112326  2024.01.05         Medium    PO-19195  Thiết bị gia dụng
# 2    NA-2011-112326      1/5/24            Low    PO-19195  Thiết bị gia dụng
# 3    NA-2011-112326      1/5/24            Low    PO-19195  Thiết bị gia dụng
# 4    TN-2011-141817      1/6/24         Medium    MB-18085  Thiết bị gia dụng
# ..              ...         ...            ...         ...                ...
# 498  HT-2011-127166     5/21/24         Medium    KH-16360  Thiết bị gia dụng
# 499  HT-2011-127166     5/21/24            Low    KH-16360  Thiết bị gia dụng
# 500  HT-2011-127166     5/21/24            Low    KH-16360  Thiết bị gia dụng
# 501  HC-2011-130673     5/20/24            Low    MC-17590  Thiết bị gia dụng
# 502  HC-2011-113768     5/13/24         Medium    AH-10030  Thiết bị gia dụng
#
#         Province            Region Channel       Product_ID    Sales  \
# 0    Hồ Chí Minh  Miền Đông Nam Bộ   Store  OFF-PA-10000174   16.448
# 1        Nghệ An        Miền Trung  Online  OFF-LA-10003223   11.784
# 2        Nghệ An        Miền Trung  Online  OFF-ST-10002743  272.736
# 3        Nghệ An  Miền Đông Nam Bộ  Online  OFF-BI-10004094    3.540
# 4      Tây Ninh   Miền Đông Nam Bộ   Store  OFF-AR-10003478   19.536
# ..           ...               ...     ...              ...      ...
# 498      Hà Tỉnh        Miền Trung   Agent  OFF-PA-10001560    4.832
# 499      Hà Tỉnh        Miền Trung   Agent  OFF-BI-10000977   18.240
# 500      Hà Tỉnh        Miền Trung   Agent  OFF-BI-10000977   18.240
# 501  Hồ Chí Minh  Miền Đông Nam Bộ   Agent  OFF-ST-10000636   66.960
# 502  Hồ Chí Minh  Miền Đông Nam Bộ   Agent  FUR-CH-10002439  279.456
#
#      Quantity  Unit_Price  Discount   Profit Returned_Reason  \
# 0         2.0       8.224       0.2   5.5512       No reason
# 1         3.0       3.928       0.2   4.2717              ""
# 2         3.0      90.912       0.2 -64.7748              ""
# 3         2.0         NaN       0.8  -5.4870             NaN
# 4         3.0       6.512       0.2   4.8840             NaN
# ..        ...         ...       ...      ...             ...
# 498       1.0       4.832       0.2   1.6308             NaN
# 499       3.0       6.080       0.8 -31.0080             NaN
# 500       3.0       6.080       0.8 -31.0080             NaN
# 501       5.0      13.392       0.2 -13.3920             NaN
# 502       6.0      46.576       0.2  20.9592             NaN
#
#             Customer_Name Customer_Segment Birthday  Phone number    Province
# 0             Darren Tran         Consumer  1/11/70   909123123.0    Vĩnh Long
# 1           Phillina Ober      Home Office  9/14/84   909123124.0       TP HCM
# 2           Phillina Ober      Home Office  9/14/84   909123124.0       TP HCM
# 3           Phillina Ober      Home Office  9/14/84   909123124.0       TP HCM
# 4              Trần Nhiễm         Consumer  1/11/96   909123127.0   Bình Dương
# ..                    ...              ...      ...           ...          ...
# 498              Trần Đức         Consumer  1/11/87   909123536.0       Hà Nội
# 499              Trần Đức         Consumer  1/11/87   909123536.0       Hà Nội
# 500              Trần Đức         Consumer  1/11/87   909123536.0       Hà Nội
# 501  Nguyễn Thị Thu Hường        Corporate  1/11/79   909123609.0      Hà Tỉnh
# 502      Trương Thanh Vân        Corporate  1/11/80   909123504.0  Hồ Chí Minh
#
# [503 rows x 20 columns]

# %% [markdown]
# ### 1.4. Data preprocessing: Product

# %%
df_prod = pd.read_csv(working_path + 'lab03_Product.csv')

# %% [markdown]
# ### 1.5. Join 2 df: Orders_Customers with Product

# %%
df_final = df_orders_cus_1.merge(df_prod, on="Product_ID", how="left")

# %% [markdown]
# ### 1.6. Các bước thực hiện:
#
#
# *   Lần lượt đọc và xử lý các file riêng lẻ
# *   Merge or Union các file lại với nhau để lấy đầy đủ thông tin
# *   File sau khi đã được gom lại, tiến hành xử lý và kiểm tra

# %% [markdown]
# #### Yêu cầu:
#
#
# *   B1: Đọc và tiền xử lý các file Lab03_Orders_Q1 và Lab03_Orders_Q2. Union 2 file này lại với nhau.
# *   B2: Đọc và tiền xử lý các file Lab03_Cus
# *   B3: Đọc và tiền xử lý các file Lab03_Product
# *   B4: Join file Orders ở B1 với file Cus ở B2
# *   B5: Join file Orders_Cus ở B4 với file Product ở B3

# %% [markdown]
# ## 2. Data Analytics

# %% [markdown]
# Dữ liệu sử dụng:
#
# Bảng: Orders_clean (các cột đã cung cấp)
# Bảng tham chiếu: customer_info, product_info
#
# Mục tiêu cuối cùng:
# Dùng trực quan hóa để tìm ra xu hướng, mẫu hình, bất thường và trả lời câu hỏi:“Điều gì đã xảy ra trong hoạt động kinh doanh?”

# %% [markdown]
# ### Task 1 — Phân tích xu hướng theo thời gian
# Vẽ biểu đồ:
#
# - Sales theo tháng/năm
#
# - Profit theo tháng/năm
#
# - Số lượng Orders theo thời gian
#
# Câu hỏi cần trả lời:
#
# - Doanh thu tăng hay giảm theo thời gian?
#
# - Có yếu tố mùa vụ không?

# %% [markdown]
# ### Task 2 — Phân tích theo khu vực (Region/Province)
# - Sales/Profit theo Region
#
# - Top Province theo Sales
#
# - So sánh Profit margin giữa các Region
#
# Câu hỏi:
#
# Khu vực nào bán nhiều nhưng lợi nhuận thấp?

# %% [markdown]
# ### Task 3 — Phân tích theo Customer
# Vẽ:
#
# Sales theo Industry_name
# Top khách hàng theo doanh thu (Pareto 80/20)
# Industry vs Region (heatmap)
#
# Câu hỏi:
#
# Nhóm khách hàng chính là ai?

# %% [markdown]
# ### Task 4 — Phân tích Returned_Reason
#
# Vẽ:
#
# - Tỷ lệ Returned theo Product / Region / Channel
# - Phân bố Returned_Reason
#
# Câu hỏi:
#
# - Trả hàng tập trung ở đâu? Vì sao?

# %% [markdown]
# ### Task 5 ( Optional): Xây dựng Dashboard
# Dashboard cần có:
#
# - KPI: Total Sales, Profit, Orders, Return Rate
# - Bộ lọc: Thời gian, Region, Channel, Industry, Product
# - Lựa chọn một số biểu đồ chính thể hiện lên dashboard

# %% [markdown]
# ## 3. Data scientist

# %% [markdown]
# **Mục tiêu**:
# Xây dựng một mô hình Regression để dự đoán Profit của đơn hàng dựa trên dữ liệu đã làm sạch.
#
# Dữ liệu sử dụng:
#
# Orders_clean (đã join với customer_info, product_info)
#
# Biến mục tiêu (target): Profit

# %% [markdown]
# Task 1 — Chuẩn bị dữ liệu cho mô hình
# - Chọn các biến đầu vào phù hợp
# - Xử lý dữ liệu
#   + Encode biến phân loại (categorical)
#   + Chuẩn hoá dữ liệu số (nếu cần)
#   + Loại bỏ missing / outlier nghiêm trọng
#
# Task 2 — Chia tập train/test
#
# Task 3 — Huấn luyện mô hình Regression cơ bản: Linear Regression
#
# Task 4 — Đánh giá mô hình
# Sử dụng các metric:
# - MAE
# - RMSE
# - R²
#
# Task 5 — Phân tích Feature Importance
#
# - Xác định biến nào ảnh hưởng nhiều nhất đến Profit
#
# - Giải thích ngắn gọn kết quả

# %% [markdown]
# ## 4. Homework

# %% [markdown]
# Yêu cầu: Sinh viên thực hiện bài tập với ba vai trò như sau:
#
# - Vai trò Data Engineer: Xử lý các file dữ liệu đầu vào, chuẩn hoá và làm sạch dữ liệu, sau đó tạo ra một file dữ liệu sạch dùng chung.
# - Vai trò Data Analyst: Sử dụng tập dữ liệu sạch bởi data engineer, hãy trực quan hoá dữ liệu bằng các biểu đồ, khám phá dữ liệu và trả lời các câu hỏi đã nêu ở Mục 2. Data Analytics.
# - Vai trò Data Scientist: Xây dựng mô hình regression để dự đoán Profit và đưa ra nhận xét về kết quả.

# %% [markdown]
# Yêu cầu nộp bài: Nộp file .ipynb với cú pháp: MSSV_Hoten_HW1.ipynb
# - Hoten: viết liền không dấu
# - Trong file, tạo 1 text: ghi rõ thông tin của sinh viên:
#    + MSSV:
#    + Họ tên: viết tên đầy đủ có dấu
# Lưu ý: Cần nộp định dạng file .ipynb
